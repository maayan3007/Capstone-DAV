# %% [markdown]
# # <font color=blue>Capstone in Data Analytics and Visualization</font>
#
#
# ## World Happines Analysis
#
# ### DAV-6500
#
# #### Project by : Adva Asraf, Dean Pianica, Maayan Raviv, Olga Kriyokov
# ***

# %% [markdown]
# # Table Of Content

# %% [markdown]
# 1. [Introduction](#1.)
#
# 2. [Description of the problem](#2.)
#
# 3. [Research Questions](#3.)
#
# 4. [Inspection of the data](#4.)
#
#     4.1. [The Happiness Report Dataset :](#4.1.)
#
#     4.2. [Happiness Alcohol Consumption Dataset](#4.2.)
#
#     4.3. [Countries of The World Datasets](#4.3.)
#
# 5. [Reading datasets from GitHub Repository](#5.)
#
# 6. [Data Set Clean Up](#6.)
#
#     6.1. [Merging all datasets into one complete dataset](#6.1.)
#
#     6.2. [Removing region columns](#6.2.)
#
#     6.3. [Removing commas](#6.3.)
#
#     6.4. [Get the mean of each column without considering NaN values](#6.4.)
#
#     6.5. [Replace NaN with mean of each column](#6.5.)
#
#     6.6. [Countries aggregation](#6.6.)
#
#     6.7. [Add continent column](#6.7.)
#
#     6.8. [Climate distribution](#6.8.)
#
#     6.9. [Add Country code](#6.9.)
#
# 7. [Exploratory Data Analysis](#7.)
#
#     7.1. [Life satisfaction across the globe](#7.1.)
#
#     7.2. [Top 3 countries that has the highest total happiness score](#7.2.)
#
# 8. [Correlation coefficient analysis](#8.)
#
# 9. [Boxplot for each continent per ladder](#9.)
#
# 10. [Correlation coefficient between countries in each continent](#10.)
#
#     10.1. [Correlation coefficient Matrix - Europe](#10.1.)
#
#     10.2. [Correlation coefficient Matrix - North America](#10.2.)
#
#     10.3. [Correlation between social support to birthrate - in North america](#10.3.)
#
#     10.4. [Correlation coefficient Matrix -  South America](#10.4.)
#
#     10.5. [Correlation between wine per capita to the GDP in south america](#10.5.)
#
#     10.6. [Correlation coefficient Matrix - Austrlia](#10.6.)
#
#     10.7. [Correlation coefficient Matrix - Asia](#10.7.)
#
#        10.7.1. [Correlation between health life expectancy to birthrate in Asia](#10.7.1.)
#
#     10.8. [Correlation coefficient Matrix - Africa](#10.8.)
#
# 11. [The highest rank per country](#11.)
#
#     11.1. [Top ten ranking countries by ladder](#11.1.)
#
#     11.2. [Top 10 Countries According to the Different Parameters](#11.2.)
#
# 12. [The Lowest rank per country](#12.)
#
# 13. [Alcohol consumption](#13.)
#
#     13.1. [Top 100 countries with the highest total alcohol consumption](#13.1.)
#
#     13.2. [Top 100 countries - Beer consumption](#13.2.)
#
#     13.3. [Top 100 countries - Wine consumption](#13.3.)
#
#     13.4. [Top 10 countries with wine consumption](#13.4.)
#
#     13.5. [Top 100 countries - spirit consumption](#13.5.)
#
#     13.6. [Top 10 countries with spirit consumption](#13.6.)
#
#     13.7. [Total alcohol consumption vs ladder line chart](#13.7.)
#
#     13.8. [Total alcohol consumption vs Positive effect](#13.8.)
#
#     13.9. [Total alcohol consumption vs Freedom](#13.9.)
#
# 14. [Climate Analysis](#14.)
#
#     14.1. [Ladder vs climate using box plot](#14.1.)
#
# 15. [Histogram for each continent per ladder](#15.)
#
# 16. [Conclusions](#16.)
#
# 17. [References](#17.)

# %% [markdown]
# ### 1. Introduction
#
# Theologians, psychologists, philosophers and economists have long sought to define what happiness truly is; there is a dedicated branch in psychology that aims to do just that. Happiness is a state of well- being that encompasses living a life one would want, with a sense of meaning and deep contentment. Happiness can also improve one’s physical health; feelings of positivity and fulfillment seem to benefit cardiovascular health, the immune system, inflammation levels, blood pressure, among other things. Furthermore, it is believed that happiness is also linked to a longer lifespan due to the fact that people who feel truly happy would like to live longer to continue striving for well-being.
#
# Attaining happiness is a global pursuit in which we all take part in. People from every corner of the world tend to rate happiness more as more important than other desirable personal outcomes.
#
# There are many factors that go into what makes people happy, it is not a target that once achieved will last for eternity. Money has been linked to happiness but only to a certain point along with genetic makeup, life circumstances, achievements, social relationships, career paths sense of freedom, one’s surrounding and place of living.
#
# It seems as if happiness has a huge impact in shaping one’s life, feelings and overall attitude. Those factors have led to the fact that happiness is increasingly considered an important and useful way to guide public policy, countries regulations and norms and measure its effectiveness.

# %% [markdown]
# ### 2. Description of the problem

# %% [markdown]
# The world is a rapidly changing place. Among the fastest changing aspects are those relating to how people communicate and interact with each other, whether in their schools and workplaces, their neighborhoods, or in far-flung parts of the world. One key contributor to people behavior is their level of happiness.
# Since happiness is commonly used in context of life satisfaction and overall well-being, we wanted to dig deeper into the matter to see what variables might influence the happiness level of individuals and as a country including financial stability, social support, sense of freedom and the geographic location.
#
# Our **main goal** in this project is to study what are the main variable that have the most influence on the life evaluation ladder, the correlation between those variables and how they affect one another.
# In order to perform a granular analysis to the best of our ability and to find out which factors contribute most to the level of happiness people feel within, we set out to analyze three different datasets while comparing and correlating the variables. Each dataset presented us with different variable to correlate and consider on our task to find out what makes us happy.
# Since every dataset is rich in data, we encountered some obstacles, especially when we combined all the datasets into one taking into account that not all variables will be needed for our analysis and therefore should be eliminating without having an effect on the remaining values and data.
# Another obstacle we were able to overcome was reviewing and altering the data-sets’ shapes and columns in order for it to match and sync altogether.
#
# Upon completion of the analysis, we were lucky to learn new key abilities Python was able to provide us in order to perform our analysis and derive crucial insights as to what makes people around the world happy.
# Furthermore, while trying to improve and advance our capabilities we pursued and took upon ourselves two additional challenges; cloud computing and application coding. Needless to mention, those two tasks were very hard to complete, took countless of hours and have brought out our best capabilities.
#
# **Cloud computing**
#
# Cloud computing is the on-demand availability of data storage and computing power without direct active management by the user. There are many data centers and cloud services nowadays that provide the user with different cloud storage and server capabilities that are always available online. We chose to use Amazon’s and Goggle’s platforms for our project.
# Since neither one of us had any experience with cloud computing at work nor school, we ran into many obstacles until we pinned down the exact way to go about it.
# We researched how exactly cloud computing works before we were able to implement our code and analysis there. We started out with looking at each platform’s infrastructure, platform and services. After watching several tutorials and reading online guidebooks, we were able to implement our analysis on the cloud’s servers and to sync the data.
# World Happiness Report Application
#
# As mentioned before, we believe that every single one of us pursues happiness throughout our lives. And as we were lucky enough to learn, we determined which factors have the most effect on people’ perception of happiness.
# However, an average person most probably would not review the World Happiness Reports often and compare and correlate between the factors that go into determining happiness levels just for the sake of it. We wanted to provide people with the chance to explore the data, but in a fun and interactive way. Therefore, we created a simple, six question survey, that aims to predict which countries the surveyor will be happiest living in according to his values and opinions. The results are based upon previous happiness scores from the past 5 years.
# Coding the application was not very simple nor intuitive, it took a lot of effort and practice. We used the K-nearest neighbor algorithm and standard normalization which we were not so familiar with.
# Another hold-back was building the dictionary that maps between the output prediction and the country associated with such prediction and training the model to predict the correct values based upon the training sets.
# We believe that our final code predicts the output correctly according to the user’s answers.
#
# **World Happiness Report Application**
# As mentioned before, we believe that every single one of us pursues happiness throughout our lives. And as we were lucky enough to learn, we determined which factors have the most effect on people’ perception of happiness.
# However, an average person most probably would not review the World Happiness Reports often and compare and correlate between the factors that go into determining happiness levels just for the sake of it. We wanted to provide people with the chance to explore the data, but in a fun and interactive way. Therefore, we created a simple, six question survey, that aims to predict which countries the surveyor will be happiest living in according to his values and opinions. The results are based upon previous happiness scores from the past 5 years.
# Coding the application was not very simple nor intuitive, it took a lot of effort and practice. We used the K-nearest neighbor algorithm and standard normalization which we were not so familiar with.
# Another hold-back was building the dictionary that maps between the output prediction and the country associated with such prediction and training the model to predict the correct values based upon the training sets.
# We believe that our final code predicts the output correctly according to the user’s answers.

# %% [markdown]
# ### 3. Research Questions

# %% [markdown]
# 1.	What is the overall life satisfaction around the globe?
#
# 2.	What is the overall happiness perception around the world broken down to continents?
#
# 3.	What are the factors that are most correlated and influential in each continent?
#
# 4.	What is the rank of happiness around the world broken down to countries?
#
# 5.	What kind of affect does alcohol consumption have on happiness rank and how is it correlated?
#
# 6.	What kind of alcoholic beverage consumption is most correlated with happiness rank?
#
# 7.	What kind of affect does climate have on happiness rank and how is it correlated?
#
# 8.	What kind of affect does birth-rate have on happiness rank and how is it correlated?
#
# 9.	What kind of affect does death-rate have on happiness rank and how is it correlated?

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import scipy.stats as ss
import plotly
import plotly.graph_objs as go
from collections import Counter
import matplotlib.pyplot as plt
from scipy import stats
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 200)
pd.options.mode.chained_assignment = None

def r2(x, y):
    return stats.pearsonr(x, y)[0] ** 2

# %% [markdown]
# ### 4. Inspection of the data

# %% [markdown]
# The below datasets are very informative and provide us with a wide array of variable to research:

# %% [markdown]
# #### 4.1. The Happiness Report Dataset

# %% [markdown]
# • https://worldhappiness.report/ed/2018/
#
# The World Happiness Report originally downloaded from www.kaggle.com. It is a well-known source of cross-country data and research on self-reported life satisfaction. The scores represent the answers to the main question that evaluate life happiness. This score is known as the Cantril Ladder, and it asks respondents to describe their livesand rate their current lives on a scale of 0-10.
#
# The most recent report was released at the United Nations at an event celebrating International Day of Happiness. The report ranks 156 countries by their happiness levels. The Happiness Score is driven by the next factors — economic production, social support, life expectancy, freedom, absence of corruption, and generosity.
#
# **Technical variables explanations:**
#
# The next variables are used to reflect what is important in explaining national- level differences in life evaluations:
#
# * GDP per capita is in terms of Purchasing Power Parity (PPP). This information was taken from the World Development Indicators (WDI) released by the World Bank.
#
# * Log of GDP per capita - The extent to which GDP contributes to the calculation of the Happiness Score.
#
# * Healthy life expectancy((HLE) are constructed based on data from the World Health Organization (WHO) Global Health Observatory data repository
#
# * Social support is - is the national average of the binary responses (either 0 or 1) to the Gallup World Poll (GWP) question “If you were in trouble, do you have relatives or friends you can count on to help you whenever you need them, or not?”
#
# * Freedom - to make life choices is the national average of responses to the GWP question “Are you satisfied or dissatisfied with your freedom to choose what you do with your life?”.
#
# * Generosity - is the residual of regressing the national average of GWP responses to the question “Have you donated money to a charity in the past month?” on GDP per capita.
#
# * Corruption - The measure is the national average of the survey responses to two questions in the GWP: “Is corruption widespread throughout the government or not” and “Is corruption widespread within businesses or not?”.
#
# * Positive affect - Measure of Positive emotion, defined as the average of previous-day affect measures for happiness, laughter, and enjoyment
#
# * Negative affect - Measure of Negative emotion, defined as the average of previous-day affect measures for worry, sadness, and anger for all waves.

# %% [markdown]
# #### 4.2. Happiness Alcohol Consumption Dataset

# %% [markdown]
# https://www.kaggle.com/marcospessotto/happiness-and-alcohol-consumption
# According to new studies that been conducted recently, alcohol consumption has been dramatically change from the 1960's and it has been confirmed, that consuming alcohol makes you happier (https://www.shape.com/healthy-eating/healthy-drinks/confirmed-drinking-alcohol-really-does-make-you-happier)
#
# This dataset was originally downloaded from https://www.kaggle.com/marcospessotto/happiness-and-alcohol-consumption, and contains data from 2016 about Happiness, HDI (Human Development Index by United Nations Development Program) and GDP score versus the alcohol per capita consumption (by country and kind of drink). We are willing to analyze those factors in order to determine if alcohol has any effect on people’s happiness.
#
# **Technical variables explanations:**
#
# * Country - Name of the country
# * Region - Region the country belongs to
# * Hemisphere - Hemisphere of country
# * Happiness Score - A metric measured by asking the sampled people the question: "How would you rate your happiness on a scale of 0 to 10 where 10 is the happiest"
# * HDI - Human Development Index by United Nations Development Program
# * GDP_PerCapita - Gross Domestic Product index
# * Beer_PerCapitaLiters ( per capita ) of beer consumption
# * Spirit_PerCapitaConsumption of spirits drink ( per capita )
# * Wine_PerCapitaWine consumption
#
# The main purpose of this dataset is to explore whether alcohol is related to higher life evaluation ladder
# Since our focus is on alcohol consumption, we will explore only the following variables: Beer, spirit and wine consumption.

# %% [markdown]
# #### 4.3. Countries of The World Datasets

# %% [markdown]
# https://www.kaggle.com/fernandol/countries-of-the-world
#
# This data set was compiled by Gene Shackman, Ph.D. for the Global Social Change Research Project. The report presents information compiled from the U.S. Government about 227 countries around the world. The reports present Information on population, region, area size, infant mortality and more. In order to concentrate on variables that could have a direct link to the happiness level of individuals and countries, we cleaned the data and chose to test the correlations of just those variables we believe will be highly correlated to happiness level.

# %% [markdown]
# ### 5. Reading datasets from GitHub Repository

# %%
CSV_file_source = "https://raw.githubusercontent.com/maayan3007/Capstone-DAV/master/world%20happiness%20report.csv"
main_dataset = pd.read_csv(
    CSV_file_source, 
    index_col=False)
main_dataset.rename(columns={'Country (region)':'Country'}, inplace=True)
main_dataset['Country'] = main_dataset['Country'].apply(str.strip)
main_dataset.head()
# Out:
#        Country  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0      Finland       1             4             41.0             10.0
# 1      Denmark       2            13             24.0             26.0
# 2       Norway       3             8             16.0             29.0
# 3      Iceland       4             9              3.0              3.0
# 4  Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# ...

# %%
CSV_file_source = "https://raw.githubusercontent.com/maayan3007/Capstone-DAV/master/hapiness%20alcohol%20consumption.csv"
data_consumption = pd.read_csv(
    CSV_file_source, 
    index_col=False)
data_consumption = data_consumption[['Country', 'Region', 'Beer_PerCapita', 'Spirit_PerCapita', 'Wine_PerCapita']]
data_consumption['Country'] = data_consumption['Country'].apply(str.strip)
data_consumption.head()
# Out:
#        Country          Region  Beer_PerCapita  Spirit_PerCapita  \
# 0      Denmark  Western Europe             224                81
# 1  Switzerland  Western Europe             185               100
# 2      Iceland  Western Europe             233                61
# 3       Norway  Western Europe             169                71
# 4      Finland  Western Europe             263               133
#
#    Wine_PerCapita
# 0             278
# 1             280
# 2              78
# 3             129
# 4              97

# %%
CSV_file_source = "https://raw.githubusercontent.com/maayan3007/Capstone-DAV/master/world%20facts.csv"
data_development = pd.read_csv(
    CSV_file_source, 
    index_col=False)
data_development = data_development[['Country', 'Region', 'Pop. Density (per sq. mi.)', 'GDP ($ per capita)', 'Infant mortality (per 1000 births)', 'Climate', 'Birthrate', 'Deathrate']]
data_development['Country'] = data_development['Country'].apply(str.strip) # Remove tailing space in each country value
data_development.head()
# Out:
#           Country                               Region  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)
# 1         Albania  EASTERN EUROPE
# 2         Algeria  NORTHERN AFRICA
# 3  American Samoa  OCEANIA
# 4         Andorra  WESTERN EUROPE
#
#   Pop. Density (per sq. mi.)  GDP ($ per capita)  \
# 0                       48,0               700.0
# 1                      124,6              4500.0
# 2                       13,8              6000.0
# 3                      290,4              8000.0
# 4                      152,1             19000.0
#
#   Infant mortality (per 1000 births) Climate Birthrate Deathrate
# 0                             163,07       1      46,6     20,34
# 1                              21,52       3     15,11      5,22
# 2                                 31       1     17,14      4,61
# 3                               9,27       2     22,46      3,27
# 4                               4,05       3      8,71      6,25

# %% [markdown]
# ### 6. Data Set Clean Up
# In order to use and read the data sets properly, the following operations were performed:
# * reviewing data set shape
# * Merging the tables
# * Removing duplicate columns
# * Null values check and filling
# * Fixing columns names and values

# %% [markdown]
# #### 6.1. Merging all datasets into one complete dataset
# As we mentioned above, we merged all 3 datasets together, to be able to get the complete picture of our data

# %%
dataset_all = pd.merge(main_dataset, data_consumption, on='Country', how='left')
dataset_all = pd.merge(dataset_all, data_development, on='Country', how='left')

# %% [markdown]
# #### 6.2. Removing region columns

# %%
try:
    del dataset_all['Region_x']
    del dataset_all['Region_y']
except:
    print("Already removed duplicate columns")

# %% [markdown]
# #### 6.3. Removing commas
# We noticed that numbers in certain columns, represented by commas, to make the numbers more readable, we removed the commas.

# %%
def remove_comma(value):
    try:
        return value.replace(",", ".")
    except:
        return value
    
dataset_all['Pop. Density (per sq. mi.)'] = dataset_all['Pop. Density (per sq. mi.)'].apply(remove_comma).astype(float)
dataset_all['Infant mortality (per 1000 births)'] = dataset_all['Infant mortality (per 1000 births)'].apply(remove_comma).astype(float)
dataset_all['Birthrate'] = dataset_all['Birthrate'].apply(remove_comma).astype(float)
dataset_all['Deathrate'] = dataset_all['Deathrate'].apply(remove_comma).astype(float)

# %% [markdown]
# #### 6.4. Get the mean of each column without considering NaN values

# %%
dataset_all.dropna().mean()
# Out:
# Ladder                                   69.271739
# SD of Ladder                             76.836957
# Positive affect                          69.173913
# Negative affect                          71.282609
# Social support                           67.728261
# Freedom                                  72.434783
# Corruption                               76.010870
# Generosity                               79.565217
# Log of GDP\nper capita                   72.173913
# Healthy life\nexpectancy                 67.521739
# Beer_PerCapita                          143.021739
# Spirit_PerCapita                         96.565217
# Wine_PerCapita                           67.891304
# Pop. Density (per sq. mi.)              166.931522
# GDP ($ per capita)                    10617.391304
# Infant mortality (per 1000 births)       34.623370
# Birthrate                                21.151413
# Deathrate                                10.175326
# dtype: float64

# %% [markdown]
# #### 6.5. Replace NaN with mean of each column

# %%
dataset_all["Positive affect"] = dataset_all["Positive affect"].fillna(69.2)
dataset_all["Negative affect"] = dataset_all["Negative affect"].fillna(71.3)
dataset_all["Social support"] = dataset_all["Social support"].fillna(67.7)
dataset_all["Freedom"] = dataset_all["Freedom"].fillna(72.4)
dataset_all["Corruption"] = dataset_all["Corruption"].fillna(76.0)
dataset_all["Generosity"] = dataset_all["Generosity"].fillna(79.6)
dataset_all["Log of GDP\nper capita"] = dataset_all["Log of GDP\nper capita"].fillna(72.2)
dataset_all["Healthy life\nexpectancy"] = dataset_all["Healthy life\nexpectancy"].fillna(67.5)
dataset_all["Beer_PerCapita"] = dataset_all["Beer_PerCapita"].fillna(143.0)
dataset_all["Spirit_PerCapita"] = dataset_all["Spirit_PerCapita"].fillna(96.6)
dataset_all["Wine_PerCapita"] = dataset_all["Wine_PerCapita"].fillna(67.9)
dataset_all["Pop. Density (per sq. mi.)"] = dataset_all["Pop. Density (per sq. mi.)"].fillna(166.9)
dataset_all["GDP ($ per capita)"] = dataset_all["GDP ($ per capita)"].fillna(10617.4)
dataset_all["Infant mortality (per 1000 births)"] = dataset_all["Infant mortality (per 1000 births)"].fillna(34.6)
dataset_all["Birthrate"] = dataset_all["Birthrate"].fillna(21.2)
dataset_all["Deathrate"] = dataset_all["Deathrate"].fillna(10.2)

dataset_all.head()
# Out:
#        Country  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0      Finland       1             4             41.0             10.0
# 1      Denmark       2            13             24.0             26.0
# 2       Norway       3             8             16.0             29.0
# 3      Iceland       4             9              3.0              3.0
# 4  Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy  Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita  \
# ...

# %%
dataset = dataset_all.copy()

# %% [markdown]
# #### 6.6. Countries aggregation
#
# We decided that we also want to compare and explore the different variables in a higher level - continent level.
#
# Due to that, we added a new variable - continent, that contains all the countries that related to that continent. Using this aggregation will provide us a macro level picture to be able to analyze the continents and see the difference between them.

# %%
asia = ["Israel", "United Arab Emirates", "Singapore", "Thailand", "Taiwan", 
        "Qatar", "Saudi Arabia", "Kuwait", "Bahrain", "Malaysia", "Uzbekistan", "Japan",
        "South Korea", "Turkmenistan", "Kazakhstan", "Turkey", "Hong Kong", "China", "Philippines",
        "Jordan", "Pakistan", "Indonesia", "Azerbaijan", "Lebanon", "Vietnam",
        "Tajikistan", "Bhutan", "Kyrgyzstan", "Nepal", "Mongolia", "Palestinian Territories",
        "Iran", "Bangladesh", "Myanmar", "Iraq", "Sri Lanka", "Armenia", "India", "Georgia",
        "Cambodia", "Afghanistan", "Yemen", "Syria", 'Laos']

europe = ["Norway", "Denmark", "Iceland", "Switzerland", "Finland", "Netherlands", "Sweden", 
          "Austria", "Ireland", "Germany", "Belgium", "Luxembourg", "United Kingdom", 
          "Czech Republic", "Malta", "France", "Spain", "Slovakia", "Poland", "Italy", 
          "Russia", "Lithuania", "Latvia", "Moldova", "Romania", "Slovenia", "Northern Cyprus", 
          "Cyprus", "Estonia", "Belarus", "Serbia", "Hungary", "Croatia", "Kosovo", 
          "Montenegro", "Greece", "Portugal", "Bosnia and Herzegovina", "Macedonia", "Bulgaria", 
          "Albania", "Ukraine"]

north_america = ["Canada", "Costa Rica", "United States", "Mexico",  
                 "Panama","Trinidad and Tobago", "El Salvador", "Guatemala",
                 "Jamaica", "Nicaragua", "Dominican Republic", "Honduras",
                 "Haiti"]

south_america = ["Chile", "Brazil", "Argentina", "Uruguay",
                 "Colombia", "Ecuador", "Bolivia", "Peru",
                 "Paraguay", "Venezuela"]

australia = ["New Zealand", "Australia"]

# %% [markdown]
# #### 6.7. Add continent column

# %%
d_europe = dict.fromkeys(europe, 'Europe')
d_north_america = dict.fromkeys(north_america, 'North America')
d_south_america = dict.fromkeys(south_america, 'South America')
d_australia = dict.fromkeys(australia, 'Australia')
d_asia = dict.fromkeys(asia, 'Asia')

continent_dict = {**d_asia, **d_europe, **d_north_america, **d_south_america, **d_australia}

dataset = dataset.assign(Continent = dataset["Country"].map(continent_dict)) 


dataset['Continent'] = dataset['Continent'].fillna("Africa")

# %% [markdown]
# #### 6.8. Climate distribution

# %% [markdown]
# After reviewing the climate values, we found out that there are many missing climate values in many countries, we decided that in order to fill those values, we chose to fill them with the mean value in the related continent of this specific country.
#
# The following climate values represent the next descriptions:
#
# 1 - Dry Tropical or Tundra & Ice
#
# 2 - Wet Tropical
#
# 3 - Temperate humid sub tropical
#
# 4 - Dry hot summer and wet winter
#
# 5 - Not mentioned'.

# %%
fig, ax = plt.subplots(2, 3, figsize=(12, 8))

a = list(dataset[dataset['Continent']=='Asia'].dropna()['Climate'])
letter_counts = Counter(a)
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar', legend=False, ax=ax[0,0])
ax[0,0].set_title("Asia")

a = list(dataset[dataset['Continent']=='Europe'].dropna()['Climate'])
letter_counts = Counter(a)
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar', legend=False, ax=ax[0,1])
ax[0,1].set_title("Europe")

a = list(dataset[dataset['Continent']=='North America'].dropna()['Climate'])
letter_counts = Counter(a)
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar', legend=False, ax=ax[0,2])
ax[0,2].set_title("North America")

a = list(dataset[dataset['Continent']=='South America'].dropna()['Climate'])
letter_counts = Counter(a)
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar', legend=False, ax=ax[1,0])
ax[1,0].set_title("South America")

a = list(dataset[dataset['Continent']=='Australia'].dropna()['Climate'])
letter_counts = Counter(a)
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar', legend=False, ax=ax[1,1])
ax[1,1].set_title("Australia")

a = list(dataset[dataset['Continent']=='Africa'].dropna()['Climate'])
letter_counts = Counter(a)
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar', legend=False, ax=ax[1,2])
ax[1,2].set_title("Africa")

plt.show()

# %%
dataset['Climate'] = np.where(dataset['Continent']=="Asia", '1', dataset['Climate'])
dataset['Climate'] = np.where(dataset['Continent']=="Europe", '3', dataset['Climate'])
dataset['Climate'] = np.where(dataset['Continent']=="North America", '2', dataset['Climate'])
dataset['Climate'] = np.where(dataset['Continent']=="South America", '2', dataset['Climate'])
dataset['Climate'] = np.where(dataset['Continent']=="Australia", '3', dataset['Climate'])
dataset['Climate'] = np.where(dataset['Continent']=="Africa", '2', dataset['Climate'])

# %% [markdown]
# At this point, we want to return all records that have missing values, until we get to a point where we have no data with empty values

# %%
null_data = dataset[dataset.isnull().any(axis=1)]
null_data
# Out:
# Empty DataFrame
# Columns: [Country, Ladder, SD of Ladder, Positive affect, Negative affect, Social support, Freedom, Corruption, Generosity, Log of GDP
# per capita, Healthy life
# expectancy, Beer_PerCapita, Spirit_PerCapita, Wine_PerCapita, Pop. Density (per sq. mi.), GDP ($ per capita), Infant mortality (per 1000 births), Climate, Birthrate, Deathrate, Continent]
# Index: []

# %% [markdown]
# #### 6.9. Add Country code

# %% [markdown]
# In order to create heat map, that includes all countries, we decided to create a new column that will represent country code. This new column represent our key column that will hold unique data which identifies record from all the other records in our datasets.

# %%
country_code_mapper = {'Afghanistan': 'AFG', 'Albania': 'ALB', 'Algeria': 'DZA', 'American Samoa': 'ASM', 'Andorra': 'AND', 'Angola': 'AGO', 'Anguilla': 'AIA',
    'Antigua and Barbuda': 'ATG', 'Argentina': 'ARG', 'Armenia': 'ARM', 'Aruba': 'ABW', 'Australia': 'AUS', 'Austria': 'AUT',
    'Azerbaijan': 'AZE', 'Bahamas, The': 'BHM', 'Bahrain': 'BHR', 'Bangladesh': 'BGD', 'Barbados': 'BRB', 'Belarus': 'BLR',
    'Belgium': 'BEL', 'Belize': 'BLZ', 'Benin': 'BEN', 'Bermuda': 'BMU', 'Bhutan': 'BTN', 'Bolivia': 'BOL', 'Bosnia and Herzegovina': 'BIH',
    'Botswana': 'BWA', 'Brazil': 'BRA', 'British Virgin Islands': 'VGB','Brunei': 'BRN', 'Bulgaria': 'BGR', 'Burkina Faso': 'BFA',
    'Burma': 'MMR', 'Burundi': 'BDI', 'Cabo Verde': 'CPV', 'Cambodia': 'KHM', 'Cameroon': 'CMR', 'Canada': 'CAN', 'Cayman Islands': 'CYM',
    'Central African Republic': 'CAF', 'Chad': 'TCD', 'Chile': 'CHL', 'China': 'CHN', 'Colombia': 'COL', 'Comoros': 'COM',
    'Cook Islands': 'COK', 'Costa Rica': 'CRI', 'Croatia': 'HRV', 'Cuba': 'CUB', 'Curacao': 'CUW', 'Cyprus': 'CYP', 'Czech Republic': 'CZE',
    'Denmark': 'DNK', 'Djibouti': 'DJI', 'Dominica': 'DMA', 'Dominican Republic': 'DOM', 'Ecuador': 'ECU', 'Egypt': 'EGY',
    'El Salvador': 'SLV', 'Equatorial Guinea': 'GNQ', 'Eritrea': 'ERI', 'Estonia': 'EST', 'Ethiopia': 'ETH', 'Falkland Islands (Islas Malvinas)': 'FLK',
    'Faroe Islands': 'FRO', 'Fiji': 'FJI', 'Finland': 'FIN', 'France': 'FRA', 'French Polynesia': 'PYF', 'Gabon': 'GAB',
    'Gambia, The': 'GMB', 'Georgia': 'GEO', 'Germany': 'DEU', 'Ghana': 'GHA', 'Gibraltar': 'GIB', 'Greece': 'GRC', 'Greenland': 'GRL',
    'Grenada': 'GRD', 'Guam': 'GUM', 'Guatemala': 'GTM', 'Guernsey': 'GGY', 'Guinea-Bissau': 'GNB', 'Guinea': 'GIN', 'Guyana': 'GUY',
    'Haiti': 'HTI', 'Honduras': 'HND', 'Hong Kong': 'HKG', 'Hungary': 'HUN', 'Iceland': 'ISL', 'India': 'IND', 'Indonesia': 'IDN',
    'Iran': 'IRN', 'Iraq': 'IRQ', 'Ireland': 'IRL', 'Isle of Man': 'IMN', 'Israel': 'ISR', 'Italy': 'ITA', 'Jamaica': 'JAM',
    'Japan': 'JPN', 'Jersey': 'JEY', 'Jordan': 'JOR', 'Kazakhstan': 'KAZ', 'Kenya': 'KEN', 'Kiribati': 'KIR', 'Korea, North': 'PRK',
    'Korea, South': 'KOR', 'Kosovo': 'KSV', 'Kuwait': 'KWT', 'Kyrgyzstan': 'KGZ', 'Laos': 'LAO', 'Latvia': 'LVA', 'Lebanon': 'LBN',
    'Lesotho': 'LSO', 'Liberia': 'LBR', 'Libya': 'LBY', 'Liechtenstein': 'LIE', 'Lithuania': 'LTU', 'Luxembourg': 'LUX', 'Macau': 'MAC',
    'Macedonia': 'MKD', 'Madagascar': 'MDG', 'Malawi': 'MWI', 'Malaysia': 'MYS', 'Maldives': 'MDV', 'Mali': 'MLI', 'Malta': 'MLT',
    'Marshall Islands': 'MHL', 'Mauritania': 'MRT', 'Mauritius': 'MUS', 'Mexico': 'MEX', 'Micronesia, Federated States of': 'FSM',
    'Moldova': 'MDA', 'Monaco': 'MCO', 'Mongolia': 'MNG', 'Montenegro': 'MNE', 'Morocco': 'MAR', 'Mozambique': 'MOZ',
    'Namibia': 'NAM', 'Nepal': 'NPL', 'Netherlands': 'NLD', 'New Caledonia': 'NCL', 'New Zealand': 'NZL', 'Nicaragua': 'NIC',
    'Nigeria': 'NGA', 'Niger': 'NER', 'Niue': 'NIU', 'Northern Mariana Islands': 'MNP', 'Norway': 'NOR', 'Oman': 'OMN',
    'Pakistan': 'PAK', 'Palau': 'PLW', 'Panama': 'PAN', 'Papua New Guinea': 'PNG', 'Paraguay': 'PRY', 'Peru': 'PER', 'Philippines': 'PHL',
    'Poland': 'POL', 'Portugal': 'PRT', 'Puerto Rico': 'PRI', 'Qatar': 'QAT', 'Romania': 'ROU', 'Russia': 'RUS', 'Rwanda': 'RWA',
    'Saint Kitts and Nevis': 'KNA', 'Saint Lucia': 'LCA', 'Saint Martin': 'MAF', 'Saint Pierre and Miquelon': 'SPM',
    'Saint Vincent and the Grenadines': 'VCT', 'Samoa': 'WSM', 'San Marino': 'SMR', 'Sao Tome and Principe': 'STP',
    'Saudi Arabia': 'SAU', 'Senegal': 'SEN', 'Serbia': 'SRB', 'Seychelles': 'SYC', 'Sierra Leone': 'SLE', 'Singapore': 'SGP',
    'Sint Maarten': 'SXM', 'Slovakia': 'SVK', 'Slovenia': 'SVN', 'Solomon Islands': 'SLB', 'Somalia': 'SOM', 'South Africa': 'ZAF',
    'South Sudan': 'SSD', 'Spain': 'ESP', 'Sri Lanka': 'LKA', 'Sudan': 'SDN', 'Suriname': 'SUR', 'Swaziland': 'SWZ', 'Sweden': 'SWE',
    'Switzerland': 'CHE', 'Syria': 'SYR', 'Taiwan': 'TWN', 'Tajikistan': 'TJK', 'Tanzania': 'TZA', 'Thailand': 'THA', 'Timor-Leste': 'TLS',
    'Togo': 'TGO', 'Tonga': 'TON', 'Trinidad and Tobago': 'TTO', 'Tunisia': 'TUN', 'Turkey': 'TUR', 'Turkmenistan': 'TKM', 'Tuvalu': 'TUV',
    'Uganda': 'UGA', 'Ukraine': 'UKR', 'United Arab Emirates': 'ARE', 'United Kingdom': 'GBR', 'United States': 'USA', 'Uruguay': 'URY',
    'Uzbekistan': 'UZB', 'Vanuatu': 'VUT', 'Venezuela': 'VEN', 'Vietnam': 'VNM', 'Virgin Islands': 'VGB', 'West Bank': 'WBG',
    'Yemen': 'YEM', 'Zambia': 'ZMB', 'Zimbabwe': 'ZWE', 'South Korea': 'KOR', 'Northern Cyprus': 'CYP', 'Ivory Coast': 'CIV', 
    'Congo (Brazzaville)': 'COG', 'Palestinian Territories': 'PSE', 'Gambia': 'GMB', 'Congo (Kinshasa)': 'COD', 'Myanmar': 'MMR'
}
dataset = dataset.assign(CountryCode = dataset["Country"].map(country_code_mapper))

# %% [markdown]
# ### 7. Exploratory Data Analysis

# %% [markdown]
# #### 7.1. Life satisfaction across the globe
#
# The bellow map visualization represent the general life satisfaction around the globe determined by the ladder value. The lower the ladder value is, the higher satisfaction level - which is determined by the green color.

# %%
plotly.offline.init_notebook_mode(connected=True)

ChoroplethMapData = dataset.copy() 

ChoroplethMapData['text'] = ChoroplethMapData['Country'] + " <br>Rank:  " + ChoroplethMapData['Ladder'].astype(str)

scl = [
    [0.0, 'green'],
    [1.0, 'red']
]

data = [
    go.Choropleth(
        colorscale = scl,
        autocolorscale = False,
        locations = ChoroplethMapData['CountryCode'],
        z = ChoroplethMapData['Ladder'],
        text = ChoroplethMapData['text'],
        marker = go.choropleth.Marker(
            line = go.choropleth.marker.Line(
                width = 1
            )),
        colorbar = go.choropleth.ColorBar(
            title = "Ladder")
    )
]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Life satisfaction across the globe'
    ),
    geo = go.layout.Geo(
        showframe=False,
        showcoastlines=True,
    )
)

fig = go.Figure(data = data, layout = layout)

plotly.offline.iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="d0ea105a-ce7c-4d06-9d14-dc14addf2691" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d0ea105a-ce7c-4d06-9d14-dc14addf2691")) {
#                     Plotly.newPlot(
# ...

# %% [markdown]
# From the map above, it is clearly to see that North America is the only continent where all states are green. This represent high satisfaction around all countries in United States. Additionally, Africa is the continent that has the lowest life satisfaction and with highest ladder values that are marked in red.
#
# <br>
# In depth, South Sudan has the highest score of being the most unsatisfied country in this continent with a rank score of 156. After that comes Central African Republic, with a total rank of 155. As you can see from the map visualizations, most of Africa's countries, have a very low satisfaction rank accept of Saudi Arabia. This can be explained by poor level of economics, low level of GDP etc. As you can see, in 2018, Saudi Arabia has been ranked as the second happiest country after Israel. According to this link (http://www.arabnews.com/node/1469981/saudi-arabia) ,
# it seems that this country has made some major changes and climb five places comparing to previous years, as this site also cited, Saudi Arabia earned the third place among the Middle East, after Israel and UAE (United Arab Emirates) in front. As you can see from the map above, our data does not include any data about UAE.
#
#
# On the contrary, looking on North and South America map, all North America's countries, are having a high score of satisfaction rate, where Canada has a higher score than the U.S. Browsing at South America map, we found that Venezuela is the only country that has the lowest score among all other countries. According to this site - https://qz.com/1267005/venezuelas-crisis-has-made-it-one-of-the-unhappiest-countries-in-the-world/, Venezuela has become one of the unhappiest countries in the world due to some major political changes, poverty that includes food shortages, salaries that cannot support family life.

# %% [markdown]
# #### 7.2. Top 3 countries that has the highest total happiness score

# %%
top_3_in_each = sorted_by_score.groupby('Continent')['Ladder'].nsmallest(3)
top_3_in_each = top_3_in_each.reset_index()
top_3_in_each.rename(columns={'level_1':'index'}, inplace=True)
top_3_in_each = pd.merge(top_3_in_each, sorted_by_score.reset_index()[['index', 'Country']], on='index', how='left')
top_3_in_each
# Out:
#         Continent  index  Ladder               Country
# 0          Africa     56      57             Mauritius
# 1          Africa     71      72                 Libya
# 2          Africa     84      85               Nigeria
# 3            Asia     12      13                Israel
# 4            Asia     20      21  United Arab Emirates
# 5            Asia     24      25                Taiwan
# 6       Australia      7       8           New Zealand
# 7       Australia     10      11             Australia
# 8          Europe      0       1               Finland
# 9          Europe      1       2               Denmark
# 10         Europe      2       3                Norway
# 11  North America      8       9                Canada
# 12  North America     11      12            Costa Rica
# 13  North America     18      19         United States
# 14  South America     25      26                 Chile
# 15  South America     31      32                Brazil
# ...

# %%
plt.bar(top_3_in_each[top_3_in_each['Continent']=="Africa"]['Country'], top_3_in_each[top_3_in_each['Continent']=="Africa"]['Ladder'])
plt.title("Top 3 Countries in Africa")
plt.show()

plt.bar(top_3_in_each[top_3_in_each['Continent']=="Asia"]['Country'], top_3_in_each[top_3_in_each['Continent']=="Asia"]['Ladder'])
plt.title("Top 3 Countries in Asia")
plt.show()

plt.bar(top_3_in_each[top_3_in_each['Continent']=="Australia"]['Country'], top_3_in_each[top_3_in_each['Continent']=="Australia"]['Ladder'])
plt.title("Top 3 Countries in Australia")
plt.show()

plt.bar(top_3_in_each[top_3_in_each['Continent']=="Europe"]['Country'], top_3_in_each[top_3_in_each['Continent']=="Europe"]['Ladder'])
plt.title("Top 3 Countries in Europe")
plt.show()

plt.bar(top_3_in_each[top_3_in_each['Continent']=="North America"]['Country'], top_3_in_each[top_3_in_each['Continent']=="North America"]['Ladder'])
plt.title("Top 3 Countries in North America")
plt.show()

plt.bar(top_3_in_each[top_3_in_each['Continent']=="South America"]['Country'], top_3_in_each[top_3_in_each['Continent']=="South America"]['Ladder'])
plt.title("Top 3 Countries in South America")
plt.show()

# %% [markdown]
# ###  8. Correlation coefficient analysis
# In order to analyze the different variables, we were needed to create table of correlations that includes all variables from all 3 datasets. After that, we will be able to create a heat map in order to understand and emphasize which type of correlation we have - positive or negative correlation. This relationship between variables determines how the right conclusions are reached.
# The main purpose of it, is to review if there is any relationship between specific variables in order to draw the right conclusion from a statistical analysis, in that way that will show that some characteristics affect others.

# %%
corr_matrix = dataset.corr()
corr_matrix
# Out:
#                                       Ladder  SD of Ladder  Positive affect  \
# Ladder                              1.000000      0.539362         0.490842
# SD of Ladder                        0.539362      1.000000         0.085152
# Positive affect                     0.490842      0.085152         1.000000
# Negative affect                     0.522619      0.619006         0.389810
# Social support                      0.816137      0.599062         0.386445
# Freedom                             0.545499      0.251687         0.681809
# Corruption                          0.185559      0.254875         0.205401
# Generosity                          0.495657      0.392156         0.354787
# Log of GDP\nper capita              0.800880      0.622954         0.293786
# Healthy life\nexpectancy            0.805801      0.604257         0.324660
# Beer_PerCapita                     -0.421658     -0.335445        -0.192093
# ...

# %%
sns.set()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, linewidths=.5, ax=ax, fmt='.1g');
plt.title("All COntinents Matrix")
plt.show()

# %% [markdown]
# In general, positive correlation implies an increase of one quantity causes an increase in the other whereas in negative correlation, an increase in one variable will cause a decrease in the other.
# __The following correlation provide the following conclusions -__
# __Correlation above 0.8 - will provide us information on how strongly pairs of variables are related:__
# * Ladder and Log of GDP per capita- This positive correlation means that the higher the ladder is which represent the overall satisfaction, the higher the GDP per capita is, which is a measure of a country's economic output that accounts for its number of people.
# </br>
# * Ladder and Healthy life Expectancy- The positive correlation means that the highest the ladder is, which represent the overall satisfaction, the higher the healthy life expectancy is. This shows us, that this measure has high effective on the overall satisfaction.
# </br>
# * Ladder and Social Support- The positive correlation means that the highest the ladder, the overall satisfaction the higher the social support expectancy which shows that this measure has high effective on the overall satisfaction.
# </br>
# * Social Support and Log of GDP per capita- The positive correlation determines that social support is more common where the log og GDP is higher which my suggest that it requires more income for people to provide it.
# </br>
# * Healthy life Expectancy and Log of GDP per capita-  The positive correlation determines that Healthy life Expectancy is more common where the log of GDP is higher which my suggest that it requires more income for people to provide it.
# </br>
# * Log of GDP per capita Infant mortality- The positive correlation suggest that infant mortality is dependent on the income level since it requires medial support.
# </br>
# * Log of GDP per capita and Birthrate- The positive correlation suggest that birthrate is effected by Log of GDP per capita, since people with less income might need more income to provide their children.
# </br>
# * Health life expectancy and infant mortality
# </br>
# * Health life expectancy and Birthrate
# </br>
# * Birthrate and infant mortality
# </br>
#
# __Correlation bellow -0.7:__
# * Ladder and GDP - seems that there is strong negative correlation between these two variables (Value of -0.7)
# * Log of GDP per capita and GDP - also here, there is strong negative correlation between these two variables (Value of -0.8)
# * Health life expectancy and GDP -seems that there is strong negative correlation between these two variables (Value of -0.7)
#
# In addition to the above correlations, it is clearly to see that alcohol consumption almost doesn’t have a strong correlation to other variables. In fact, there are few negative correlations that point that there is no/weak relationship between alcohol consumption and the ladder variable.

# %%
sorted_highest_data = dataset.sort_values(by='Birthrate', ascending=False)
sorted_highest_data.head(100)
# Out:
#                       Country  Ladder  SD of Ladder  Positive affect  \
# 113                     Niger     114           144             79.0
# 127                      Mali     128            96             48.0
# 135                    Uganda     136           148             91.0
# 153               Afghanistan     154            25            152.0
# 128              Sierra Leone     129           153            139.0
# 131                      Chad     132           139            136.0
# 114              Burkina Faso     115            92            115.0
# 111                   Somalia     112            74              2.0
# 140                   Liberia     141           156            103.0
# 149                    Malawi     150           132            129.0
# 150                     Yemen     151            85            153.0
# 144                   Burundi     145           138             98.0
# 117                    Guinea     118           146             82.0
# ...

# %%
sorted_highest_data = sorted_highest_data.head(10)
plt.figure(figsize=(15,8))
plt.bar(sorted_highest_data['Country'], sorted_highest_data['Birthrate'])
plt.title("Top 10 countries with highest Birthrate")
plt.show()

# %% [markdown]
# Since birth rate has some strong positive correlations with other variables, we decided to explore in which continent we can find the highest birth rate. In this chart, we will present the top 10 countries that have the highest birth rate. As we inspected, all of the countries above are related to Africa.

# %% [markdown]
# #### Top 10 countries with highest Infant mortality (per 1000 births)

# %%
sorted_highest_data = sorted_highest_data.head(10)
plt.figure(figsize=(15,8))
plt.bar(sorted_highest_data['Country'], sorted_highest_data['Infant mortality (per 1000 births)'])
plt.title("Top 10 countries with infant mortality")
plt.show()

# %% [markdown]
# ###  9. Boxplot for each continent per ladder
#
# The following boxplots explore the distributional characteristics of a ladder of continent as well as the level of the ladder.
# The boxplot of South America is comparatively short, this suggests that overall states have a high similarity in the ladder's scores.
# The box plot of Asia and Europe is comparatively higher to South America and Australia, this suggests that the states in those continents hold different ladder scores.
# Africa's box plot is much higher than South America, this could suggest a difference between the states in those continents in terms of the ladder score.
# In North America the 4 sections of the box plot are uneven in size. This shows that many states have similar ladder score at certain parts of the scale, but in other parts of the scale the ladder scores of the states are more variable.
# Any obvious difference between box plots for comparative groups is worthy of further investigation.

# %% [markdown]
# #### Overall boxplot between continent to ladder

# %%
grouped = dataset[['Continent', 'Ladder']].groupby('Continent')
grouped.boxplot(subplots=False, figsize=(15, 10), showfliers=False)
plt.title("Continent vs Ladder")
plt.show()

# %% [markdown]
# ### 10. Correlation coefficient between countries in each continent
# Bellow we will review and analyze if the correlation values are different among the continents in order to understand if those correlations effect the importance of variables in people lives. We will explore each continent separately

# %% [markdown]
# ####  10.1. Correlation coefficient Matrix - Europe

# %%
corr_matrix = dataset[dataset['Continent']=="Europe"].corr()

# %%
sns.set()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, linewidths=.5, ax=ax, fmt='.1g');
plt.title("Europe")
plt.show()

# %% [markdown]
# From the map above, you can clearly see that there are some strong positive and negative correlations.
# We find a strong positive correlation between the next variables:
#
# **Positive correlation:**
#
# * Ladder value and freedom -  This means that the higher level of freedom is, the evaluation life ladder is higher too. It seems that people satisfaction from life has high dependancy on thier freedom in their country.
#
# * Positive affect and ladder - The higher previous-day affect measures for happiness, laughter, and enjoyment is, the higher the evaluation life ladder is.
#
# * There is a strong positive correlation between healthy life expectancy and ladder value. This means that people that are having healthy life expectancy, like to be more satisfied with a higher life evaluation ladder
#
# * Infant mortality and Log GDP per capita - it means that the higher the GDP contribution to the calculation of the Happiness  Score is, the higher infant mortality.
#
#
# * Healthy life expectancy and Log GDP per capita -  it means that the higher the GDP contribution to the calculation of the Happiness  Score is, the level of the Healthy life expectancy is higher.
#
# * Positive affect and freedom - it seems the more freedom that inhabitants get in Europe, the measure o positive affect is higher.
#
# If we will analyze the ladder variable among the other variable, and compare it to our complete matrix, we will see that both have positive correlation coefficient, but as you can see, Europe has a stronger coefficient than the complete matrix
#
#
# Additionally, there is a positive correlation between death rate and spirit per capita. This represent that the higher the spirit consumption is, the death rate increase simultaneously
#
#
# **Negative correlation:**
#
# If we look at the GDP per capita in Europe among the other variables, it is clearly to see that there is a strong negative correlation between that specific variable and all other variables. This chain of negative correlations, do not exist in the total matrix, and this fact differentiate Europe from the rest of the world. Seems that as the GDP increase, all the other variables like: ladder, positive affect, social support, freedom, corruption, generosity, log of GDP and Healthy life expectancy decrease.

# %% [markdown]
# ####  10.2. Correlation coefficient Matrix - North America

# %%
corr_matrix = dataset[dataset['Continent']=="North America"].corr()

# %%
sns.set()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, linewidths=.5, ax=ax, fmt='.1g');
plt.title("North America")
plt.show()

# %% [markdown]
# In the North America correlation matrix, the major difference in correlation was inspected at the correlation between social supports to birthrate that suggest that the level of social support effect the birthrate significant in North America.
# In addition to that, the variable of spirit per capita and Positive effect, it seems like the habits of Alcohol consuming has a larger effect on people positive effect then in other continents.
#
# You can also observe the correlation between the ladders to the GDP is higher which is comprehensive since it's well known that the GDP level is higher in North America comparing to other continents and it has a bigger effect on the overall ranking.
#
# As you can additionally can see, North America Matrix obtained a 0.9 correlation coefficient values between the next variables:
#
# 1. Spirit per capita and positive effect.
# 2. Positive affect and ladder.
# 3. Log of GDP and birth rate
# 4. Social support and birth rate
# 5. Infant mortality and healthy life expectancy
# 6. Birth rate and infant mortality
# 7. GDP and wine per capita
#
# This represent that North America differentiate herself from all the other continents and from the complete matrix with this correlation with a very strong correlation. In addition to that, it seems that the corruption and the generosity variable has negative correlation with almost all variables. This result doesn't appear in Europe.
#
# As you can find in the Europe correlation matrix, also here the GDP variable has negative correlation coefficient to all other variables, the correlation is not strong with all variable like in the Europe matrix, but you can still find some strong correlations with variables like: SD of ladder, and log of GDP.

# %% [markdown]
# #### 10.3. Correlation between social support to birthrate - in North america

# %%
sns.set()
g = sns.lmplot(x="Social support", y="Birthrate", truncate=True, data=dataset[dataset['Continent']=="North America"])
g.set_axis_labels("Social support", "Birthrate")
plt.show()

print("R Squared value =",
r2(
    dataset[dataset['Continent']=="North America"]['Birthrate'], 
    dataset[dataset['Continent']=="North America"]['Social support']
))
# Out:
# R Squared value = 0.787829883696264

# %% [markdown]
# The scatter plot above, shows in details the correlation between social support to birthrate which appears to be comparative higher in North America, it clearly shows the positive correlation emphasize that the more social support rate is higher the birthrate increase as well.

# %% [markdown]
# ####  10.4. Correlation coefficient Matrix -  South America
# The major difference in correlation was inspected in the correlation between wine per capita to the GDP which suggest that the level alcohol consuming is dependent on the GDP level in the state

# %%
corr_matrix = dataset[dataset['Continent']=="South America"].corr()

# %%
sns.set()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, linewidths=.5, ax=ax, fmt='.1g');
plt.title(" South America")
plt.show()

# %% [markdown]
# **In the South America correlation matrix, you can find the next results:**
# * There is a strong positive correlation between positive effect and negative effect (value of 0.8). This correlation appear on the results of North America, Europe and the complete matrix but not in the same strength as it appears on South America matrix.
# * There is almost no correlation between the next variables: health life expectancy and freedom, health life expectancy and corruption
#
# * Looking at the spirit per capita variable, it is clearly to see that there are certain variables that has no correlation at all with the spirit per capita variable: Negative effect, ladder, positive effect, social support, generosity, Log of GDP. This non correlation situation do not exist in North America values, and actually you can see some positive correlation with these variables.
#
# * Beer per capita - it comes out that there is a strong positive correlation between beers per capita and ladder variable. You can conclude from this that the higher the beer consumption is, the higher the ladder value is. In addition to the ladder variable, there is a strong positive correlation between beer per capita and freedom variable. The more people feel freedom in their country, their beer consumption is higher.
#
# * Wine per capita - if we take a closer look at this variable, it seems that there is moderate and strong negative correlation between wine consumption per capita and the next variables (sorted high to low values): Log of GDP, healthy life expectancy, ladder. SD of ladder and positive affect. This means that one variable increases (wine per capita) whenever the other decreases.
#
# * Generosity - not like in North America, here that generosity variable have strong positive correlation with the next variables: ladder, SD of ladder, positive effect, negative effect. That result as the beer analysis above, differentiate South America from North America.
#
# * Population density - it seems that population density has no correlation with the ladder variable, it means that the population density has no major effect on the ladder value in South Africa.

# %% [markdown]
# #### 10.5. Correlation between wine per capita to the GDP in south america

# %%
sns.set()
g = sns.lmplot(x="Wine_PerCapita", y="GDP ($ per capita)", truncate=True, data=dataset[dataset['Continent']=="North America"])
g.set_axis_labels("Wine Per Capita", "GDP ($ per capita)")
plt.show()

print("R Squared value =",
r2(
    dataset[dataset['Continent']=="North America"]['Wine_PerCapita'], 
    dataset[dataset['Continent']=="North America"]['GDP ($ per capita)']
))
# Out:
# R Squared value = 0.8948476582410231

# %% [markdown]
# Above is the scatter plot shows in details the correlation between wine per capita consumption to the GDP which appears to be comparative higher in South America, it clearly shows the positive correlation the emphasize that GDP is higher the wine consumption per capita increase as well.

# %% [markdown]
# ####  10.6. Correlation coefficient Matrix - Austrlia

# %%
corr_matrix = dataset[dataset['Continent']=="Australia"].corr()

# %%
sns.set()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, linewidths=.5, ax=ax, fmt='.1g');
plt.title(" Australia & New Zeland")
plt.show()

# %% [markdown]
# From the heat map above, it is clearly to see that we received 2 main correlation coefficients - a perfect positive correlation and a perfect negative correlation. As we examined our data set, there is two countries in this continent, therefore, we can conclude that the sample size is not big enough to receive reliable insights. While at the same time

# %% [markdown]
# #### 10.7. Correlation coefficient Matrix - Asia

# %%
corr_matrix = dataset[dataset['Continent']=="Asia"].corr()

# %%
sns.set()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, linewidths=.5, ax=ax, fmt='.1g');
plt.title(" Asia")
plt.show()

# %% [markdown]
# **In Asia correlation matrix, you can analyze the following conclusions:**
#
# * Wine per capita consumption - there is a moderate correlation between the wine consumption and the ladder variable. It seems that only this type of alcohol among the others has some relationship to the ladder value. The other types of alcohol has almost no correlation.
#
# * Asia doesn’t have many strong positive or negative correlations as the other continents. Most of the correlation are very week or no correlation at all
#
# * The major difference in correlation was inspected in the correlation between health life expectancy to birthrate and infant mortality which was significantly lower comparing to the overall correlation. In this case, we can assume that healthy life expectancy importance is lower in those states.

# %% [markdown]
# #### 10.7.1. Correlation between health life expectancy to birthrate in Asia

# %%
sns.set()
g = sns.lmplot(x="Healthy life\nexpectancy", y="GDP ($ per capita)", truncate=True, data=dataset[dataset['Continent']=="North America"])
g.set_axis_labels("Healthy life\nexpectancy", "GDP ($ per capita)")
plt.show()

print("R Squared value =",
r2(
    dataset[dataset['Continent']=="North America"]['Healthy life\nexpectancy'], 
    dataset[dataset['Continent']=="North America"]['GDP ($ per capita)']
))
# Out:
# R Squared value = 0.27744615886853474

# %% [markdown]
# In the scatter plot above we can see in details the correlation between health life expectancy to the birthrate which appears to be comparative higher in Asia, it clearly shows the positive correlation that emphasize that when the health life expectancy is higher the birthrate increase as well.

# %% [markdown]
# #### 10.8. Correlation coefficient Matrix - Africa

# %%
corr_matrix = dataset[dataset['Continent']=="Africa"].corr()

# %%
sns.set()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, linewidths=.5, ax=ax, fmt='.1g');
plt.title(" Africa")
plt.show()

# %% [markdown]
# In Africa we inspected the following:
#
# * In a very close similarity to Asia, Africa also has a very weak correlations between most of the variables.
#
# * There is two significant strong/moderate positive correlations between the variables: birth rate to infant mortality and death rate to infant mortality.
#
# * There is two main variables that have moderate positive effect on the ladder variable: Social support and Log of GDP.
#
# * There is also 2 strong negative correlations between infant mortality to GDP and between birth rate to GDP. GDP has the opposite influence on those 2 variables, once GDP is increase, the other two variables decrease.

# %% [markdown]
# ### 11. The highest rank per country

# %% [markdown]
# At the analysis above, we tried to exemine the relatioship between all variables at a more nacro level, now we will try to dive deeper with our analysis, to be able to uderstan the variables in a country level.

# %% [markdown]
# #### 11.1. Top ten ranking countries by ladder

# %%
sorted_by_ladder = dataset[['Country', 'Ladder', 'Continent']].sort_values(by=['Ladder'], ascending=True)
sorted_by_ladder = sorted_by_ladder.head(10)
sorted_by_ladder
# Out:
#        Country  Ladder      Continent
# 0      Finland       1         Europe
# 1      Denmark       2         Europe
# 2       Norway       3         Europe
# 3      Iceland       4         Europe
# 4  Netherlands       5         Europe
# 5  Switzerland       6         Europe
# 6       Sweden       7         Europe
# 7  New Zealand       8      Australia
# 8       Canada       9  North America
# 9      Austria      10         Europe

# %%
sorted_by_ladder = sorted_by_ladder.sort_values(by=['Ladder'], ascending=False)
ax = sns.barplot(x="Country", y="Ladder", data=sorted_by_ladder)
plt.ylabel('Ladder')
plt.title('Highest 10 Countries in Ladder')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As we can see from the bar chart above, 80% of the countries that were marked as the top countries that have the highest value (Value 1 in the ladder represent the highest value) are from Europe. Although Canada and United states, also have high ranking, Western Europe countries received higher ranking. According to Forbes newspaper, Europe is the happiest continent (See related link in references). United States suffering from a social crisis, unlike Europe, where people feel more vital, safe, secure and therefore happier.

# %% [markdown]
# #### 11.2. Top 10 Countries According to the Different Parameters

# %%
sorted_by_score = sorted_by_score.sort_values(by=['Ladder'], ascending=True)
sorted_by_score["Rank"] = sorted_by_score["Ladder"].rank(ascending=1, method="min")

# %%
trace1 = go.Bar(
                x = top_10['Country'],
                y = top_10['Freedom'],
                name = 'Freedom',
                marker = dict(color = 'rgba(125, 25, 200, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
trace2 = go.Bar(
                x = top_10['Country'],
                y = top_10['Log of GDP\nper capita'],
                name = "Log of GDP\nper capita",
                marker = dict(color = 'rgba(25, 25, 25, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
trace3 = go.Bar(
                x = top_10['Country'],
                y = top_10['Generosity'],
                name = "Generosity",
                marker = dict(color = 'rgba(190, 200, 100, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
trace4 = go.Bar(
                x = top_10['Country'],
                y = top_10['Social support'],
                name = "Social support",
                marker = dict(color = 'rgba(50, 150, 50, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
trace5 = go.Bar(
                x = top_10['Country'],
                y = top_10['Healthy life\nexpectancy'],
                name = "Healthy life\nexpectancy",
                marker = dict(color = 'rgba(255, 70, 12, 0.8)',
                             line = dict(color = 'rgb(0,0,0)', width = 1.5))
                )
data = [trace1, trace2, trace3, trace4, trace5]
layout = go.Layout(barmode = 'group', title = 'Top 10 Countries According to the Different Parameters')
fig = go.Figure(data = data, layout = layout)
plotly.offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="72ec77a4-2cb3-4520-ab46-754c546ab7b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("72ec77a4-2cb3-4520-ab46-754c546ab7b3")) {
#                     Plotly.newPlot(
#                         '72ec77a4-2cb3-4520-ab46-754c546ab7b3',
# ...

# %% [markdown]
# In the next bar chart, we will see the top 10 countries that has the highest total happiness score with different key factors variables: freedom, GDP, generosity, social support and healthy life expectancy. As you can see from this graph, Finland has the highest rank in generosity among all other countries. Austria has the highest rank in social support among all other countries. On the contrary, Iceland has the lowest rank in social support.
# Looking at this bar chart, you can easily learn the rank of each country that appears to be at the top 10 ranked countries

# %%
trace1 = go.Scatter(
                    x = top_10.Rank,
                    y = top_10.Freedom,
                    mode = "lines + markers",
                    name = "Freedom",
                    marker = dict(color = 'rgba(55, 20, 50, 0.9)'),
                    text = top_10.Country
                    )
trace2 = go.Scatter(
                    x = top_10.Rank,
                    y = top_10['Anti-Corruption'],
                    mode = "lines + markers",
                    name = "Corruption",
                    marker = dict(color = 'rgba(10, 180, 80, 0.9)'),
                    text = top_10.Country
                    )

trace3 = go.Scatter(
                    x = top_10.Rank,
                    y = top_10['Generosity'],
                    mode = "lines + markers",
                    name = "Generosity",
                    marker = dict(color = 'rgba(255, 0, 0, 0.9)'),
                    text = top_10.Country
                    )

trace4 = go.Scatter(
                    x = top_10.Rank,
                    y = top_10['Social support'],
                    mode = "lines + markers",
                    name = "Social support",
                    marker = dict(color = 'rgba(240, 171, 0, 0.9)'),
                    text = top_10.Country
                    )

trace5 = go.Scatter(
                    x = top_10.Rank,
                    y = top_10['Healthy life\nexpectancy'],
                    mode = "lines + markers",
                    name = "Healthy life nexpectancy",
                    marker = dict(color = 'rgba(90, 193, 166, 0.9)'),
                    text = top_10.Country
                    )

data = [trace1, trace2, trace3,trace4,trace5]
layout = dict(title = 'Top 10 ranked countries by different parameters',
             xaxis = dict(title = 'Happiness Rank', ticklen = 5, zeroline = True, tickmode='linear')
             )
fig = dict(data = data, layout = layout)
plotly.offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="512f3b5e-ec3f-4d65-b0a3-48960e6a8459" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("512f3b5e-ec3f-4d65-b0a3-48960e6a8459")) {
#                     Plotly.newPlot(
#                         '512f3b5e-ec3f-4d65-b0a3-48960e6a8459',
# ...

# %% [markdown]
# By using this line chart, you will be able to compare each parameter in different countries. This will give you a deeper view of the bar chart above.

# %% [markdown]
# ### 12. The Lowest rank per country
# Bellow are the countries that recieved the Lowest ranking in the report, the Higher the ladder value the worse the ranking.
# South Sudan is the country that recieved the lowest ranking.

# %%
sorted_by_ladder = dataset[['Country', 'Ladder', 'Continent']].sort_values(by=['Ladder'], ascending=False)
sorted_by_ladder = sorted_by_ladder.head(10)
sorted_by_ladder
# Out:
#                       Country  Ladder      Continent
# 155               South Sudan     156         Africa
# 154  Central African Republic     155         Africa
# 153               Afghanistan     154           Asia
# 152                  Tanzania     153         Africa
# 151                    Rwanda     152         Africa
# 150                     Yemen     151           Asia
# 149                    Malawi     150         Africa
# 148                     Syria     149           Asia
# 147                  Botswana     148         Africa
# 146                     Haiti     147  North America

# %%
ax = sns.barplot(x="Country", y="Ladder", data=sorted_by_ladder)
plt.ylabel('Ladder')
plt.title('Lowest 10 Countries in Ladder')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# At this bar chart, we decide to present the top ten countries that received the lowest ladder grade. Unlike the top 10 countries bar chart, in this bar chart we can see that most of the countries received almost the same score (between 147-156). 6 of the unhappiest countries are from Africa, 3 are from Asia, and 1 is from North America.

# %% [markdown]
# ### 13. Alcohol consumption
#
#
# The variables that related to alcohol consumption were merged into to the main data set in order to review if they effect the overall satisfaction.
# The map analysis bellow, present the total consumption per capita for each country.
# It's clearly shows that in most places where the ladder was relatively higher the alcohol consumption was higher as well.

# %%
consumption_data = dataset[['Country', 'CountryCode', 'Beer_PerCapita', 'Spirit_PerCapita', 'Wine_PerCapita']]
consumption_data = consumption_data.dropna()
consumption_data['total_consumption'] = consumption_data['Beer_PerCapita'] + consumption_data['Spirit_PerCapita'] + consumption_data['Wine_PerCapita']
consumption_data.head()
# Out:
#        Country CountryCode  Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita  \
# 0      Finland         FIN           263.0             133.0            97.0
# 1      Denmark         DNK           224.0              81.0           278.0
# 2       Norway         NOR           169.0              71.0           129.0
# 3      Iceland         ISL           233.0              61.0            78.0
# 4  Netherlands         NLD           251.0              88.0           190.0
#
#    total_consumption
# 0              493.0
# 1              583.0
# 2              369.0
# 3              372.0
# 4              529.0

# %%
plotly.offline.init_notebook_mode(connected=True)

ChoroplethMapData = consumption_data.copy() 

ChoroplethMapData['text'] = ChoroplethMapData['Country'] + " <br>Consumption:  " + ChoroplethMapData['total_consumption'].astype(str)

scl = [
    [0.0, 'green'],
    [1.0, 'red']
]

data = [
    go.Choropleth(
        colorscale = scl,
        autocolorscale = False,
        locations = ChoroplethMapData['CountryCode'],
        z = ChoroplethMapData['total_consumption'],
        text = ChoroplethMapData['text'],
        marker = go.choropleth.Marker(
            line = go.choropleth.marker.Line(
                width = 1
            )),
        colorbar = go.choropleth.ColorBar(
            title = "Alcohol Consumption")
    )
]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Alcohol Consumption Per Country '
    ),
    geo = go.layout.Geo(
        showframe=False,
        showcoastlines=True,
    )
)

fig = go.Figure(data = data, layout = layout)

plotly.offline.iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="9f700d7b-3892-4821-a5a2-23d3555af7fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f700d7b-3892-4821-a5a2-23d3555af7fb")) {
#                     Plotly.newPlot(
# ...

# %% [markdown]
# Looking at the map visualization above, we can see at a glance the alcohol consumption distribution. From this map we can inspect the following insights:
# * It appears that Africa and some countries in Asia (Turkmenistan. Kazakhstan, Uzbekistan), have the lowest alcohol consumption comparing to other states and continents.
# * Europe has the highest values of alcohol consumption (top 10 countries will be displayed in the following bar chart).
# * Canada and the US are also having high values, but significant lower than Europe.
#
# We will explore the top countries with high alcohol consumption in more detailed way at the next analysis

# %%
consumption_data = dataset[['Country', 'CountryCode', 'Ladder', 'Freedom', 'Positive affect', 'Beer_PerCapita', 'Spirit_PerCapita', 'Wine_PerCapita']]
consumption_data = consumption_data.dropna()
consumption_data['total_consumption'] = consumption_data['Beer_PerCapita'] + consumption_data['Spirit_PerCapita'] + consumption_data['Wine_PerCapita']
consumption_data.head()
# Out:
#        Country CountryCode  Ladder  Freedom  Positive affect  Beer_PerCapita  \
# 0      Finland         FIN       1      5.0             41.0           263.0
# 1      Denmark         DNK       2      6.0             24.0           224.0
# 2       Norway         NOR       3      3.0             16.0           169.0
# 3      Iceland         ISL       4      7.0              3.0           233.0
# 4  Netherlands         NLD       5     19.0             12.0           251.0
#
#    Spirit_PerCapita  Wine_PerCapita  total_consumption
# 0             133.0            97.0              493.0
# 1              81.0           278.0              583.0
# 2              71.0           129.0              369.0
# 3              61.0            78.0              372.0
# 4              88.0           190.0              529.0

# %% [markdown]
# #### 13.1. Top 100 countries with the highest total alcohol consumption

# %%
consumption_data = dataset[['Country', 'CountryCode', 'Ladder', 'Freedom', 'Positive affect', 'Beer_PerCapita', 'Spirit_PerCapita', 'Wine_PerCapita']]
consumption_data['Total Consumption'] = consumption_data['Beer_PerCapita'] + consumption_data['Spirit_PerCapita'] + consumption_data['Wine_PerCapita']
consumption_data = consumption_data.sort_values(by='Total Consumption', ascending=False)

consumption_data.head(100)
# Out:
#                       Country CountryCode  Ladder  Freedom  Positive affect  \
# 19             Czech Republic         CZE      20     58.0             74.0
# 23                     France         FRA      24     69.0             56.0
# 41                  Lithuania         LTU      42    122.0            138.0
# 13                 Luxembourg         LUX      14     28.0             62.0
# 16                    Germany         DEU      17     44.0             65.0
# 61                    Hungary         HUN      62    138.0             86.0
# 39                     Poland         POL      40     52.0             76.0
# 37                   Slovakia         SVK      38    108.0             53.0
# 65                   Portugal         PRT      66     37.0             97.0
# 43                   Slovenia         SVN      44     13.0            114.0
# 15                    Ireland         IRL      16     33.0             33.0
# ...

# %% [markdown]
# In the table above, you can find a list of top 100 countries with the highest total alcohol consumption

# %%
consumption_data = consumption_data.head(10)
plt.figure(figsize=(15,8))
plt.bar(consumption_data['Country'], consumption_data['Total Consumption'])
plt.title("Top 100 countries with the highest total alcohol consumption")
plt.show()

# %% [markdown]
# In this bar chart, we present the top 10 countries with the highest total alcohol consumption amount in a more graphic way. In this chart we can see that all 10 top countries are located in Europe.

# %% [markdown]
# #### 13.2. Top 100 countries - Beer consumption

# %%
consumption_data = dataset[['Country', 'CountryCode', 'Ladder', 'Freedom', 'Positive affect', 'Beer_PerCapita', 'Spirit_PerCapita', 'Wine_PerCapita']]
consumption_data = consumption_data.sort_values(by='Beer_PerCapita', ascending=False)

# %% [markdown]
# In the table above, you can find a list of top 100 countries with the highest beer consumption

# %%
consumption_data = consumption_data.head(10)
plt.figure(figsize=(15,8))
plt.bar(consumption_data['Country'], consumption_data['Beer_PerCapita'])
plt.title("Top 10 countries with beer consumption")
plt.show()

# %% [markdown]
# In this bar chart, we present the top 10 countries with the highest beer consumption amount in a more graphic way. As we inspected, the first place got Namibia and on the third place Gabon, both of the countries are in Africa. While all the other top 8, in Europe.

# %% [markdown]
# #### 13.3. Top 100 countries - Wine consumption

# %%
consumption_data = dataset[['Country', 'CountryCode', 'Ladder', 'Freedom', 'Positive affect', 'Beer_PerCapita', 'Spirit_PerCapita', 'Wine_PerCapita']]
consumption_data = consumption_data.sort_values(by='Wine_PerCapita', ascending=False)
consumption_data.head(100)
# Out:
#                       Country CountryCode  Ladder  Freedom  Positive affect  \
# 23                     France         FRA      24     69.0             56.0
# 65                   Portugal         PRT      66     37.0             97.0
# 5                 Switzerland         CHE       6     11.0             44.0
# 1                     Denmark         DNK       2      6.0             24.0
# 43                   Slovenia         SVN      44     13.0            114.0
# 13                 Luxembourg         LUX      14     28.0             62.0
# 74                    Croatia         HRV      75    118.0            122.0
# 35                      Italy         ITA      36    132.0             99.0
# 46                  Argentina         ARG      47     54.0             28.0
# 32                    Uruguay         URY      33     30.0             10.0
# 81                     Greece         GRC      82    150.0            102.0
# ...

# %% [markdown]
# #### 13.4. Top 10 countries with wine consumption

# %%
consumption_data = consumption_data.head(10)
plt.figure(figsize=(15,8))
plt.bar(consumption_data['Country'], consumption_data['Wine_PerCapita'])
plt.title("Top 10 countries with wine consumption")
plt.show()

# %% [markdown]
# In this bar chart, we present the top 10 countries with the highest spirit consumption amount in a more graphic way. As we inspected, in this chart, 9/10 of the countries at the 10 top list, are part of Europe while only one is in South America

# %% [markdown]
# #### 13.5. Top 100 countries - spirit consumption

# %%
consumption_data = dataset[['Country', 'CountryCode', 'Ladder', 'Freedom', 'Positive affect', 'Beer_PerCapita', 'Spirit_PerCapita', 'Wine_PerCapita']]
consumption_data = consumption_data.sort_values(by='Spirit_PerCapita', ascending=False)
consumption_data.head(100)
# Out:
#                       Country CountryCode  Ladder  Freedom  Positive affect  \
# 80                    Belarus         BLR      81    131.0            149.0
# 146                     Haiti         HTI     147    152.0            142.0
# 37                   Slovakia         SVK      38    108.0             53.0
# 51                   Thailand         THA      52     18.0             20.0
# 96                   Bulgaria         BGR      97    115.0            117.0
# 59                 Kazakhstan         KAZ      60     80.0             81.0
# 41                  Lithuania         LTU      42    122.0            138.0
# 132                   Ukraine         UKR     133    141.0            131.0
# 70                    Moldova         MDA      71    128.0            133.0
# 52                     Latvia         LVA      53    126.0            119.0
# 61                    Hungary         HUN      62    138.0             86.0
# ...

# %% [markdown]
# #### 13.6. Top 10 countries with spirit consumption

# %%
consumption_data = consumption_data.head(10)
plt.figure(figsize=(15,8))
plt.bar(consumption_data['Country'], consumption_data['Spirit_PerCapita'])
plt.title("Top 10 countries with spirit consumption")
plt.show()

# %% [markdown]
# In this bar chart, we present the top 10 countries with the highest spirit consumption amount in a more graphic way. As we inspected, in this bar chart we are having countries from all over the world, many countries from Eastern Europe.

# %% [markdown]
# #### 13.7. Total alcohol consumption vs ladder line chart

# %%
consumption_data = dataset[['Country', 'CountryCode', 'Ladder', 'Freedom', 'Positive affect', 'Beer_PerCapita', 'Spirit_PerCapita', 'Wine_PerCapita']]
consumption_data = consumption_data.dropna()
consumption_data['total_consumption'] = consumption_data['Beer_PerCapita'] + consumption_data['Spirit_PerCapita'] + consumption_data['Wine_PerCapita']
consumption_data.head()
# Out:
#        Country CountryCode  Ladder  Freedom  Positive affect  Beer_PerCapita  \
# 0      Finland         FIN       1      5.0             41.0           263.0
# 1      Denmark         DNK       2      6.0             24.0           224.0
# 2       Norway         NOR       3      3.0             16.0           169.0
# 3      Iceland         ISL       4      7.0              3.0           233.0
# 4  Netherlands         NLD       5     19.0             12.0           251.0
#
#    Spirit_PerCapita  Wine_PerCapita  total_consumption
# 0             133.0            97.0              493.0
# 1              81.0           278.0              583.0
# 2              71.0           129.0              369.0
# 3              61.0            78.0              372.0
# 4              88.0           190.0              529.0

# %%
sns.set(style="darkgrid")
g = sns.jointplot("total_consumption", "Ladder", data=consumption_data, kind="reg", xlim=(0, 690), ylim=(0, 170), color="m", height=7)
plt.xlabel("Total Alcohol Consumption")
plt.show()

print("R Squared value =",
r2(
    consumption_data['total_consumption'], 
    consumption_data['Ladder']
))
# Out:
# R Squared value = 0.23039512519465213

# %% [markdown]
# #### 13.8. Total alcohol consumption vs Positive effect

# %%
x = consumption_data['total_consumption']
y = consumption_data['Positive affect']

sns.set(style="darkgrid")
g = sns.jointplot("total_consumption", "Positive affect", data=consumption_data, kind="reg", xlim=(0, 690), ylim=(0, 170), color="m", height=7)
plt.xlabel("Total Alcohol Consumption")
plt.ylabel("Positive affect")
plt.show()

print("R Squared value =",
r2(
    consumption_data['total_consumption'], 
    consumption_data['Positive affect']
))
# Out:
# R Squared value = 0.019824254711332607

# %% [markdown]
# #### 13.9. Total alcohol consumption vs Freedom

# %%
x = consumption_data['total_consumption']
y = consumption_data['Freedom']

sns.set(style="darkgrid")
g = sns.jointplot("total_consumption", "Freedom", data=consumption_data, kind="reg", xlim=(0, 690), ylim=(0, 170), color="m", height=7)
plt.xlabel("Total Alcohol Consumption")
plt.show()

print("R Squared value =",
r2(
    consumption_data['total_consumption'], 
    consumption_data['Freedom']
))
# Out:
# R Squared value = 0.03608309374578379

# %% [markdown]
# **From the bar plots above, we can conclude that:**
#
# According to the r squared value which appears to be very low in all 3 plots, there is a weak correlation between the variables - freedom, ladder, positive effect and ladder. In addition, the values are highly scattered throughout the confidence ellipse and therefore also indicates that the correlation is minor. Due to the above, no further analysis will be required and we can conclude that alcohol has little affect on the ladder variable

# %% [markdown]
# ### 14. Climate Analysis

# %% [markdown]
# The variable of climate was added to the main data set in order to review if it might affect the overall satisfaction or the ladder. The boxplots bellow review the level of agreement between the weather to the ladder. Both box plots, 1,5 and 2,5 are comparatively short. This suggests that overall countries have a high level of values with each other, which is reasonable since those groups in general are smaller than the others since the weather is not defined in those groups. Box plots 1,2,3 are comparatively tall. This suggests countries hold diversity in the weather.

# %% [markdown]
# #### 14.1. Ladder vs climate using box plot

# %%
grouped = dataset[['Ladder', 'Climate']].groupby('Climate')
grouped.boxplot(subplots=False, figsize=(15, 10), showfliers=False)
plt.title("Ladder vs climate")
plt.xlabel("Climate")
plt.legend(['1 - Dry Tropical or Tundra & Ice', '2 - Wet Tropical', '3 - Temperate humid sub tropical', '4 - Dry hot summer and wet winter', '5 - Not mentioned'], handlelength=0)
plt.show()

# %% [markdown]
# ### 15. Histogram for each continent per ladder

# %%
sns.set(style="white", palette="muted", color_codes=True)

f, axes = plt.subplots(2, 3, figsize=(15, 10), sharex=True)
sns.despine(left=True)

sns.distplot(dataset[dataset['Continent']=="Europe"]['Ladder'], color="b", ax=axes[0, 0]).set_title("Ladder distribution of Europe")
sns.distplot(dataset[dataset['Continent']=="Australia"]['Ladder'], color="b", ax=axes[0, 1]).set_title("Ladder distribution of Australia")
sns.distplot(dataset[dataset['Continent']=="North America"]['Ladder'], color="b", ax=axes[0, 2]).set_title("Ladder distribution of North America")
sns.distplot(dataset[dataset['Continent']=="Asia"]['Ladder'], color="b", ax=axes[1, 0]).set_title("Ladder distribution of Asia")
sns.distplot(dataset[dataset['Continent']=="South America"]['Ladder'], color="b", ax=axes[1, 1]).set_title("Ladder distribution of South America")
sns.distplot(dataset[dataset['Continent']=="Africa"]['Ladder'], color="b", ax=axes[1, 2]).set_title("Ladder distribution of Africa")

plt.setp(axes, yticks=[])
plt.tight_layout()
plt.show()

# %% [markdown]
# The histograms above present the distribution of the ladder by continent.
# In Africa the histogram is left-skewed which means that for most countries the mean is typically less than the median.
# In North and South America there is an outlier that can be described as extremely high values that do not fall near any other data points or represent unusual cases.
# In Asia the distribution is almost uniform.
# In Australia's visualization, New Zealand is also included which leads to unrepresentative sample size
# The bin size is the same for all graphs since there aren’t any identical values in the ladder's variable.

# %% [markdown]
# ### 16. Conclusions
#
# At our research, we have putted focus on how several measures of happiness, and of its contributing factors, have influence one on each other and merged them with other population factors as well as climate factor.
# In this research we tried to answer our research questions by creating different visualizations and correlations graphs.
#
# We started to create our analysis by creating a map that will present the happiness rank in different countries, and after that w drilled down to a micro view that will giv us a bigger picture of what is happening in our globes. We made an analysis for each continent and even in each countries.
#
# We discovered that 9 of the happiest countries are located in Europe, with different levels of key factors that influence the ladder rank. It seems that Europe gained her place in the top 10 with some clear correlations that effect the ladder rank with a very strong positive correlations. It seems that there are some critical variables like: GDP, freedom, corruption, infant mortality and healthy life expectancy that effect directly the ladder rank. Regards to Europe's alcohol consumption, it seems that the most significant correlation that we have is to different spirits. While wine and beers have low and moderate negative correlation. Additionally, we discovered that the correlation between alcohol consumption (beer, wine and spirits) has almost no influence on parameters like ladder rank, positive affect and negative affect.
#
# In addition to that, we explored factors that related to the population, birth rate, death rate and infant mortality rate in each continent. We found out that Africa is the continent that has the highest birth rate and infant mortality rate. You can relate this to deficient sanitary and to poor medicine and technology.
#
# In each continent, we found the top 3 countries that have the highest happiness score. For example, in North America, United States received the highest score among the other countries. In Asia, Israel was in the top 3 among with Taiwan and the Arab Emirates. This analysis gave us a perspective on the countries and their total score.
#
# In conclusion, we think that we were able to answer all our research questions. The only thing that we have left to do, is to choose you preferred country according to your key factors measures, and for that, our app will assist you to make your best choice.

# %% [markdown]
# ### 17. References

# %% [markdown]
# https://www.kaggle.com/roshansharma/world-happiness-report
# (https://www.shape.com/healthy-eating/healthy-drinks/confirmed-drinking-alcohol-really-does-make-you-happier)
# https://www.cia.gov/library/publications/the-world-factbook/docs/notesanddefs.html#345
# https://www.forbes.com/sites/duncanmadden/2019/03/28/ranked-the-10-happiest-countries-in-the-world-in-2019/#16bad95648a5
